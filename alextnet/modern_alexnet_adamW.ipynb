# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import tensorflow as tf
from tensorflow.keras import Sequential, layers, optimizers
import matplotlib.pyplot as plt

# %%
import numpy as np
import os

def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# Define the path to the extracted dataset
cifar10_dir = './data/cifar-10-batches-py'

# Load the data batches
data_batches = []
labels = []

for i in range(1, 6):
    batch_path = os.path.join(cifar10_dir, f'data_batch_{i}')
    batch_data = unpickle(batch_path)
    data_batches.append(batch_data[b'data'])
    labels.extend(batch_data[b'labels'])

# Load the test batch
test_batch_path = os.path.join(cifar10_dir, 'test_batch')
test_batch_data = unpickle(test_batch_path)
test_data = test_batch_data[b'data']
test_labels = test_batch_data[b'labels']

# Load the labels
label_names_path = os.path.join(cifar10_dir, 'batches.meta')
label_names = unpickle(label_names_path)[b'label_names']

# Concatenate the training data and labels
train_data = np.concatenate(data_batches)
train_labels = np.array(labels)
test_labels = np.array(test_labels)

# %%
print("all the lables names: ", label_names)
print("Training data shape:", train_data.shape)
print("Training labels shape:", train_labels.shape)
print("Test data shape:", test_data.shape)
print("Test labels shape:", test_labels.shape)

train_data = train_data.reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)
test_data = test_data.reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)

print("Reshaped training data shape:", train_data.shape)
print("Reshaped test data shape:", test_data.shape)
# Out:
# all the lables names:  [b'airplane', b'automobile', b'bird', b'cat', b'deer', b'dog', b'frog', b'horse', b'ship', b'truck']
# Training data shape: (50000, 3072)
# Training labels shape: (50000,)
# Test data shape: (10000, 3072)
# Test labels shape: (10000,)
# Reshaped training data shape: (50000, 32, 32, 3)
# Reshaped test data shape: (10000, 32, 32, 3)

# %%
BATCH_SIZE = 64
AUTOTUNE = tf.data.AUTOTUNE

def preprocess(image, label):
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

train_ds = (
    tf.data.Dataset.from_tensor_slices((train_data, train_labels))
    .shuffle(10000)
    .map(preprocess, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

test_ds = (
    tf.data.Dataset.from_tensor_slices((test_data, test_labels))
    .map(preprocess, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

print("Pipeline ready")
# Out:
# Pipeline ready

# %%
epochs = 30
modern_alexnet = Sequential([
    layers.Input(shape=(32,32,3)),
    layers.Resizing(128,128),
    
    layers.Conv2D(96, 5, strides=1, padding='same'),
    layers.BatchNormalization(),
    layers.ReLU(),
    layers.MaxPooling2D(3, strides=2),
    
    layers.Conv2D(256, 5, padding='same'),
    layers.BatchNormalization(),
    layers.ReLU(),
    layers.MaxPooling2D(3, strides=2),
    
    layers.Conv2D(384, 3, padding='same'),
    layers.BatchNormalization(),
    layers.ReLU(),
    
    layers.Conv2D(384, 3, padding='same'),
    layers.BatchNormalization(),
    layers.ReLU(),
    
    layers.Conv2D(256, 3, padding='same'),
    layers.BatchNormalization(),
    layers.ReLU(),
    
    layers.MaxPooling2D(3, strides=2),
    
    layers.GlobalAveragePooling2D(),
    layers.Dense(1028, activation="relu"),
    layers.Dropout(0.5),
    layers.Dense(512, activation="relu"),
    layers.Dropout(0.5),
    layers.Dense(10, activation="softmax")
    
])

steps_per_epoch = len(train_ds)
total_steps = steps_per_epoch * epochs

lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=1e-3,
    decay_steps=total_steps,
    alpha=1e-5
)

optimizer = optimizers.AdamW(
    learning_rate=lr_schedule,
    weight_decay=1e-4
)

modern_alexnet.compile(
    optimizer=optimizer,
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)


modern_alexnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resizing (Resizing)         (None, 128, 128, 3)       0
#
#  conv2d (Conv2D)             (None, 128, 128, 96)      7296
#
#  batch_normalization (Batch  (None, 128, 128, 96)      384
#  Normalization)
#
#  re_lu (ReLU)                (None, 128, 128, 96)      0
#
#  max_pooling2d (MaxPooling2  (None, 63, 63, 96)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 63, 63, 256)       614656
#
#  batch_normalization_1 (Bat  (None, 63, 63, 256)       1024
#  chNormalization)
#  re_lu_1 (ReLU)              (None, 63, 63, 256)       0
#
#  max_pooling2d_1 (MaxPoolin  (None, 31, 31, 256)       0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 31, 31, 384)       885120
#
#  batch_normalization_2 (Bat  (None, 31, 31, 384)       1536
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 31, 31, 384)       0
#
#  conv2d_3 (Conv2D)           (None, 31, 31, 384)       1327488
#
#  batch_normalization_3 (Bat  (None, 31, 31, 384)       1536
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 31, 31, 384)       0
#
#  conv2d_4 (Conv2D)           (None, 31, 31, 256)       884992
#
#  batch_normalization_4 (Bat  (None, 31, 31, 256)       1024
#  chNormalization)
#
#  re_lu_4 (ReLU)              (None, 31, 31, 256)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 15, 15, 256)       0
#  g2D)
#
#  global_average_pooling2d (  (None, 256)               0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1028)              264196
#
#  dropout (Dropout)           (None, 1028)              0
#
#  dense_1 (Dense)             (None, 512)               526848
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 4521230 (17.25 MB)
# Trainable params: 4518478 (17.24 MB)
# Non-trainable params: 2752 (10.75 KB)
# _________________________________________________________________

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

history = modern_alexnet.fit(
    train_ds,
    epochs=epochs,
    validation_data=test_ds
)
# Out:
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1767793024.635771   22206 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 782/782 [==============================] - 69s 75ms/step - loss: 1.6970 - accuracy: 0.3604 - val_loss: 2.5918 - val_accuracy: 0.2243
# Epoch 2/30
# 782/782 [==============================] - 56s 72ms/step - loss: 1.3370 - accuracy: 0.5104 - val_loss: 2.8387 - val_accuracy: 0.2669
# Epoch 3/30
# 782/782 [==============================] - 56s 71ms/step - loss: 1.1769 - accuracy: 0.5789 - val_loss: 1.2716 - val_accuracy: 0.5271
# Epoch 4/30
# 782/782 [==============================] - 56s 72ms/step - loss: 1.0762 - accuracy: 0.6153 - val_loss: 1.3222 - val_accuracy: 0.5391
# Epoch 5/30
# 782/782 [==============================] - 55s 70ms/step - loss: 0.9872 - accuracy: 0.6476 - val_loss: 1.1068 - val_accuracy: 0.5869
# Epoch 6/30
# 782/782 [==============================] - 56s 72ms/step - loss: 0.9145 - accuracy: 0.6812 - val_loss: 1.4195 - val_accuracy: 0.5358
# Epoch 7/30
# 782/782 [==============================] - 57s 72ms/step - loss: 0.8454 - accuracy: 0.7018 - val_loss: 1.6616 - val_accuracy: 0.5015
# Epoch 8/30
# 782/782 [==============================] - 54s 70ms/step - loss: 0.7806 - accuracy: 0.7256 - val_loss: 1.1932 - val_accuracy: 0.6003
# Epoch 9/30
# 782/782 [==============================] - 57s 72ms/step - loss: 0.7291 - accuracy: 0.7461 - val_loss: 0.8704 - val_accuracy: 0.6930
# Epoch 10/30
# 782/782 [==============================] - 55s 69ms/step - loss: 0.6710 - accuracy: 0.7662 - val_loss: 0.8235 - val_accuracy: 0.7186
# Epoch 11/30
# 782/782 [==============================] - 57s 72ms/step - loss: 0.6133 - accuracy: 0.7895 - val_loss: 1.2297 - val_accuracy: 0.6255
# Epoch 12/30
# 782/782 [==============================] - 54s 69ms/step - loss: 0.5663 - accuracy: 0.8062 - val_loss: 0.8828 - val_accuracy: 0.7154
# Epoch 13/30
# 782/782 [==============================] - 57s 73ms/step - loss: 0.5199 - accuracy: 0.8229 - val_loss: 1.0467 - val_accuracy: 0.6720
# Epoch 14/30
# 782/782 [==============================] - 57s 72ms/step - loss: 0.4759 - accuracy: 0.8383 - val_loss: 0.7690 - val_accuracy: 0.7421
# Epoch 15/30
# 782/782 [==============================] - 54s 69ms/step - loss: 0.4345 - accuracy: 0.8538 - val_loss: 0.5580 - val_accuracy: 0.8054
# Epoch 16/30
# 782/782 [==============================] - 57s 73ms/step - loss: 0.3941 - accuracy: 0.8673 - val_loss: 0.8172 - val_accuracy: 0.7535
# Epoch 17/30
# 782/782 [==============================] - 57s 72ms/step - loss: 0.3594 - accuracy: 0.8767 - val_loss: 0.6145 - val_accuracy: 0.8016
# Epoch 18/30
# 782/782 [==============================] - 54s 70ms/step - loss: 0.3201 - accuracy: 0.8895 - val_loss: 0.6413 - val_accuracy: 0.7998
# Epoch 19/30
# 782/782 [==============================] - 57s 72ms/step - loss: 0.2829 - accuracy: 0.9042 - val_loss: 0.7801 - val_accuracy: 0.7679
# Epoch 20/30
# 782/782 [==============================] - 55s 70ms/step - loss: 0.2497 - accuracy: 0.9147 - val_loss: 0.5781 - val_accuracy: 0.8244
# Epoch 21/30
# 782/782 [==============================] - 56s 72ms/step - loss: 0.2180 - accuracy: 0.9258 - val_loss: 0.5687 - val_accuracy: 0.8301
# Epoch 22/30
# 782/782 [==============================] - 57s 72ms/step - loss: 0.1949 - accuracy: 0.9344 - val_loss: 0.5028 - val_accuracy: 0.8503
# Epoch 23/30
# 782/782 [==============================] - 54s 70ms/step - loss: 0.1715 - accuracy: 0.9441 - val_loss: 0.5599 - val_accuracy: 0.8427
# Epoch 24/30
# 782/782 [==============================] - 57s 72ms/step - loss: 0.1488 - accuracy: 0.9507 - val_loss: 0.5622 - val_accuracy: 0.8487
# Epoch 25/30
# 782/782 [==============================] - 56s 72ms/step - loss: 0.1273 - accuracy: 0.9588 - val_loss: 0.5327 - val_accuracy: 0.8589
# Epoch 26/30
# 782/782 [==============================] - 55s 70ms/step - loss: 0.1163 - accuracy: 0.9619 - val_loss: 0.5487 - val_accuracy: 0.8605
# Epoch 27/30
# 782/782 [==============================] - 56s 72ms/step - loss: 0.1031 - accuracy: 0.9656 - val_loss: 0.5317 - val_accuracy: 0.8643
# Epoch 28/30
# 782/782 [==============================] - 54s 70ms/step - loss: 0.0977 - accuracy: 0.9681 - val_loss: 0.5386 - val_accuracy: 0.8644
# Epoch 29/30
# 782/782 [==============================] - 57s 72ms/step - loss: 0.0916 - accuracy: 0.9708 - val_loss: 0.5372 - val_accuracy: 0.8670
# Epoch 30/30
# 782/782 [==============================] - 57s 72ms/step - loss: 0.0900 - accuracy: 0.9709 - val_loss: 0.5360 - val_accuracy: 0.8671

# %%
def plot_history(history):
  # Get accuracy and loss from history
  train_acc = history['accuracy']
  val_acc = history['val_accuracy']
  train_loss = history['loss']
  val_loss = history['val_loss']

  epochs_range = range(len(train_acc))

  # Plot Training and Validation Accuracy
  plt.figure(figsize=(12, 4))
  plt.subplot(1, 2, 1)
  plt.plot(epochs_range, train_acc, label='Training Accuracy')
  plt.plot(epochs_range, val_acc, label='Validation Accuracy')
  plt.legend(loc='lower right')
  plt.title('Training and Validation Accuracy')

  # Plot Training and Validation Loss
  plt.subplot(1, 2, 2)
  plt.plot(epochs_range, train_loss, label='Training Loss')
  plt.plot(epochs_range, val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Training and Validation Loss')

  plt.show()

# %%
plot_history(history.history)

# %%
# save the model and history
modern_alexnet.save('modern_alexnet_adamW_cifar10_model.h5')
import pickle
with open('modern_alexnet_adamW_cifar10_history.pkl', 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# /home/rover/miniconda3/envs/tf-best/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
